# %%
import os
import openai
import dotenv
from IPython.display import display, HTML


from app.prompts import system_prompt
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key = os.getenv("OPENAI_API_KEY")
os.environ['REQUESTS_CA_BUNDLE'] = '/Users/eagwu/Projects/Perso/LLM/caadmin.netskope.com.cer'

# %%
len(system_prompt)
# Out:
# 3688

# %%
class CoachBot:
    def __init__(self):
        self.context = [{'role':'system', 'content': system_prompt}]
        openai.api_key = os.getenv("OPENAI_API_KEY")
        os.environ['REQUESTS_CA_BUNDLE'] = 'caadmin.netskope.com.cer'

    def get_response(self, user_prompt):
        self.context.append({'role': 'user', 'content': user_prompt})
        response = self.get_completion(self.context)
        self.context.append({'role': 'assistant', 'content': response})
        return response

    def get_completion(self, messages, model="gpt-3.5-turbo", temperature=0.5):
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            temperature=temperature,
        )
        return response.choices[0].message["content"]
    
    def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            temperature=temperature,
        )
        return response.choices[0].message["content"]

# %%
system_message = {'role':'system', 'content': system_prompt}

# %%
age = 24
weight = 63
height = 178
sex = "man"
city = "Paris"
goal = "be athletic"
ideal_weight = 70
place = "at home"
train_freq = 3
level = "intermediate"
duration = 90
intensity = 3
discipline = 3

user_prompt = f"""I am {age} years old and i weight {weight}kg and my height is {height} cm. \
    I'm a {sex} and I live in {city} \
    My goal is to {goal}. I would love to weight {ideal_weight}kg. \
    I will exercise mainly {place} .\
    I can can manage to train {train_freq} times a week. I am at {level} level. \
    Each time I train I can spend {duration} minutes. \
    On a scale of 1 to 5 I want each session to be intense at {intensity}
    On a scale of 1 to 5 I judge my discipline is at {discipline}
    Which whorkout plan do you recommend?
"""

# %%
user_prompt
# Out:
# "I am 24 years old and i weight 63kg and my height is 178 cm.     I'm a man and I live in Paris     My goal is to be athletic. I would love to weight 70kg.     I will exercise mainly at home .    I can can manage to train 3 times a week. I am at intermediate level.     Each time I train I can spend 90 minutes.     On a scale of 1 to 5 I want each session to be intense at 3\n    On a scale of 1 to 5 I judge my discipline is at 3\n    Which whorkout plan do you recommend?\n"

# %%
chatbot = CoachBot()
response = chatbot.get_response(user_prompt)

# %%
display(HTML(response))
# Out:
# Based on your information, here's a personalized fitness plan that can help you achieve your goal of becoming more athletic and reaching a weight of 70kg:
#
# <h1>WORKOUT PLAN</h1>
# <p>To achieve your goal, we recommend a combination of strength and cardio exercises. Here's a 12-week workout plan that you can follow:</p>
# <table>
#   <tr>
#     <th>Session</th>
#     <th>Exercises</th>
#     <th>Time/Sets-Reps</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Warm-up, Push-ups, Squats, Lunges, Plank, Cool-down</td>
#     <td>10 min, 3 sets of 10 reps, 3 sets of 10 reps, 3 sets of 10 reps, 1 min hold, 5 min</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Warm-up, Pull-ups, Dips, Leg raises, Cool-down</td>
#     <td>10 min, 3 sets of 10 reps, 3 sets of 10 reps, 3 sets of 10 reps, 5 min</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Warm-up, Jumping jacks, Burpees, Mountain climbers, Cool-down</td>
#     <td>10 min, 3 sets of 10 reps, 3 sets of 10 reps, 3 sets of 10 reps, 5 min</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>Warm-up, Push-ups, Squats, Lunges, Plank, Cool-down</td>
#     <td>10 min, 3 sets of 12 reps, 3 sets of 12 reps, 3 sets of 12 reps, 1 min hold, 5 min</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>Warm-up, Pull-ups, Dips, Leg raises, Cool-down</td>
#     <td>10 min, 3 sets of 12 reps, 3 sets of 12 reps, 3 sets of 12 reps, 5 min</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>Warm-up, Jumping jacks, Burpees, Mountain climbers, Cool-down</td>
#     <td>10 min, 3 sets of 12 reps, 3 sets of 12 reps, 3 sets of 12 reps, 5 min</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>Warm-up, Push-ups, Squats, Lunges, Plank, Cool-down</td>
#     <td>10 min, 3 sets of 15 reps, 3 sets of 15 reps, 3 sets of 15 reps, 1 min 30 sec hold, 5 min</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>Warm-up, Pull-ups, Dips, Leg raises, Cool-down</td>
#     <td>10 min, 3 sets of 15 reps, 3 sets of 15 reps, 3 sets of 15 reps, 5 min</td>
#   </tr>
#   <tr>
#     <td>9</td>
#     <td>Warm-up, Jumping jacks, Burpees, Mountain climbers, Cool-down</td>
#     <td>10 min, 3 sets of 15 reps, 3 sets of 15 reps, 3 sets of 15 reps, 5 min</td>
#   </tr>
#   <tr>
#     <td>10</td>
#     <td>Warm-up, Push-ups, Squats, Lunges, Plank, Cool-down</td>
#     <td>10 min, 3 sets of 18 reps, 3 sets of 18 reps, 3 sets of 18 reps, 2 min hold, 5 min</td>
#   </tr>
#   <tr>
#     <td>11</td>
#     <td>Warm-up, Pull-ups, Dips, Leg raises, Cool-down</td>
#     <td>10 min, 3 sets of 18 reps, 3 sets of 18 reps, 3 sets of 18 reps, 5 min</td>
#   </tr>
#   <tr>
#     <td>12</td>
#     <td>Warm-up, Jumping jacks, Burpees, Mountain climbers, Cool-down</td>
#     <td>10 min, 3 sets of 18 reps, 3 sets of 18 reps, 3 sets of 18 reps, 5 min</td>
#   </tr>
# </table>
# <p>Make sure to rest for 30-60 seconds between sets and 1-2 minutes between exercises. It's important to gradually increase the intensity and difficulty of your workouts over time to avoid plateauing. We also recommend incorporating some form of cardio exercise, such as running or jumping rope, for 20-30 minutes after your strength training sessions.</p>
#
#
# <h1>NUTRITION PLAN</h1>
# <p>Nutrition is a crucial component of any fitness plan. Here are three meal suggestions for breakfast, lunch, and dinner:</p>
# <table>
#   <tr>
#     <th>Meal</th>
#     <th>Food</th>
#     <th>Portion</th>
#   </tr>
#   <tr>
#     <td>Breakfast</td>
#     <td>Scrambled eggs, whole grain toast, avocado</td>
#     <td>2 eggs, 2 slices of toast, 1/2 avocado</td>
#   </tr>
#   <tr>
#     <td>Lunch</td>
#     <td>Grilled chicken breast, quinoa, mixed veggies</td>
#     <td>4-6 oz chicken, 1 cup quinoa, 1 cup veggies</td>
#   </tr>
#   <tr>
#     <td>Dinner</td>
#     <td>Salmon fillet, sweet potato, steamed broccoli</td>
#     <td>4-6 oz salmon, 1 medium sweet potato, 1 cup broccoli</td>
#   </tr>
# </table>
# <p>Make sure to eat a balanced diet with plenty of protein, complex carbohydrates, and healthy fats. Drink plenty of water throughout the day and limit your intake of processed foods and sugary drinks.</p>
#
#
# <h1>SLEEPING SCHEDULE</h1>
# <p>Sleep is crucial for muscle recovery and overall health. We recommend getting 7-9 hours of sleep each night and maintaining a consistent sleep schedule. Here are some tips to help you achieve quality sleep:</p>
# <ul>
#   <li>Avoid caffeine and alcohol before bedtime</li>
#   <li>Create a relaxing bedtime routine, such as reading or taking a warm bath</li>
#   <li>Make sure your sleeping environment is cool, dark, and quiet</li>
#   <li>Avoid using electronic devices before bedtime</li>
# </ul>
# <p>Try to stick to a consistent sleep schedule, even on weekends, to help regulate your body's internal clock.</p>
#
#
# <h1>DISCIPLINE TIPS</h1>
# <p>Staying disciplined and committed to your fitness plan can be challenging, but here are some tips to help you stay on track:</p>
# <ul>
#   <li>Set realistic goals and track your progress</li>
#   <li>Find a workout buddy or accountability partner</li>
#   <li>Mix up your workouts to avoid boredom</li>
#   <li>Reward yourself for reaching milestones</li>
#   <li>Stay positive and don't be too hard on yourself if you slip up</li>
# </ul>
# <p>Remember, consistency is key to achieving your fitness goals.</p>
#
#
# <h1>Ideal Day</h1>
# <p>Here's an example of an ideal day that can help you stay on track with your fitness plan:</p>
# <ul>
#   <li>6:30am - Wake up and have breakfast</li>
#   <li>7:30am - Start your workout</li>
#   <li>9:00am - Shower and get ready for the day</li>
#   <li>10:00am - Work or school</li>
#   <li>12:30pm - Lunch</li>
#   <li>1:30pm - Resume work or school</li>
#   <li>5:30pm - Finish work or school</li>
#   <li>6:00pm - Cardio exercise or rest day</li>
#   <li>7:00pm - Dinner</li>
#   <li>8:00pm - Relaxation time (read, watch TV, etc.)</li>
#   <li>10:00pm - Start winding down for bed</li>
#   <li>11:00pm - Lights out</li>
# </ul>
# <p>Remember to listen to your body and adjust your schedule as needed. Consistency is key, but it's also important to take rest days and give your body time to recover.</p>
#
# <form action="/download_pdf" method="post">
#   <button class="download-btn" type="submit">Download as PDF</button>
# </form>

# %%
print (response)
# Out:
# Based on your personal circumstances and fitness goals, I recommend the following workout plan:
#
# <h1>WORKOUT PLAN</h1>
# <p>Congratulations on taking the first step towards achieving your fitness goals! This workout plan is tailored to help you become more athletic and reach your desired weight of 70kg. You will be training 3 times a week, for 90 minutes each session, with an intensity level of 3 out of 5. This plan is designed for intermediate level fitness enthusiasts who prefer to exercise at home.</p>
#
# <table>
#   <tr>
#     <th>Session</th>
#     <th>Exercises</th>
#     <th>Estimated Time/Sets-Reps</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Warm-up: Jumping Jacks, Push-ups, Squats, Lunges, Plank</td>
#     <td>10 minutes</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Push-ups</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Squats</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Lunges</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Plank</td>
#     <td>3 sets of 30 seconds</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Crunches</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Warm-up: Jumping Jacks, Push-ups, Squats, Lunges, Plank</td>
#     <td>10 minutes</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Push-ups</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Squats</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Lunges</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Plank</td>
#     <td>3 sets of 30 seconds</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Leg Raises</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Warm-up: Jumping Jacks, Push-ups, Squats, Lunges, Plank</td>
#     <td>10 minutes</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Push-ups</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Squats</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Lunges</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Plank</td>
#     <td>3 sets of 30 seconds</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Mountain Climbers</td>
#     <td>3 sets of 12 reps</td>
#   </tr>
# </table>
#
# <p>It is important to gradually increase the intensity and difficulty of your workout as you progress. Remember to stay hydrated and take breaks when necessary. Consistency is key to achieving your fitness goals, so make sure to stick to your training schedule and push yourself to reach your full potential.</p>

# %%
display(HTML("app/templates/index.html"))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Coachbot in the building !!</title>
#     <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
# </head>
# <body>
#     <div class="form-container">
#         <form method="post" action="/generate_pdf">
#             <label for="age">Age:</label>
#             <input type="number" name="age" id="age" required><br>
#
#             <label for="weight">Weight (kg):</label>
#             <input type="number" name="weight" id="weight" required><br>
#
#             <label for="height">Height (cm):</label>
#             <input type="number" name="height" id="height" required><br>
#
#             <label for="sex">Sex:</label>
#             <select name="sex" id="sex" required>
#                 <option value="man">Man</option>
#                 <option value="woman">Woman</option>
#             </select><br>
#
#             <label for="city">City:</label>
#             <input type="text" name="city" id="city" required><br>
#
#             <label for="goal">Goal:</label>
#             <input type="text" name="goal" id="goal" required><br>
#
#             <label for="ideal_weight">Ideal Weight (kg):</label>
#             <input type="number" name="ideal_weight" id="ideal_weight" required><br>
#
#             <label for="place">Place of Exercise:</label>
#             <input type="text" name="place" id="place" required><br>
#
#             <label for="train_freq">Training Frequency:</label>
#             <input type="number" name="train_freq" id="train_freq" required><br>
#
#             <label for="level">Training Level:</label>
#             <select name="level" id="level" required>
#                 <option value="beginner">Beginner</option>
#                 <option value="intermediate">Intermediate</option>
#                 <option value="advanced">Advanced</option>
#             </select><br>
#
#             <label for="duration">Training Duration (minutes):</label>
#             <input type="number" name="duration" id="duration" required><br>
#
#             <label for="intensity">Training Intensity (1-5):</label>
#             <input type="number" name="intensity" id="intensity" min="1" max="5" required><br>
#
#             <label for="discipline">Discipline (1-5):</label>
#             <input type="number" name="discipline" id="discipline" min="1" max="5" required><br>
#
#             <button type="submit">Get my GymPlan</button>
#         </form>
#     </div>
# </body>
# </html>
